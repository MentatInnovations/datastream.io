# %%
from dsio.main import restream_dataframe
from dsio.anomaly_detectors import Percentile1D
import pandas as pd
dataframe = pd.read_csv('data/cardata_sample.csv', sep=',')
detector = Percentile1D
restream_dataframe(dataframe, detector, sensors=['engine_speed',
                                                   'vehicle_speed', 
                                                   'accelerator_pedal_position', 
                                                   'torque_at_transmission'], cols=2, speed=50)
# Out:
# data found from 2013-05-24 21:21:37 to 2013-05-24 21:44:13
# Converting to milliseconds ...
# Done
# Adding time offset of 147583238.27 seconds
# Setting speed to 50x
# Done
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b459503b-dce1-45d3-860b-9e84c1bb12dc">Loading BokehJS ...</span>
#     </div>
# <script
#     src="http://localhost:60861/autoload.js?bokeh-autoload-element=6fd31445-e684-46f5-b4bf-6ed63b941477&bokeh-absolute-url=http://localhost:60861"
#     id="6fd31445-e684-46f5-b4bf-6ed63b941477"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>
# Writing 150 rows dated 2018-01-26 23:42:15.668000 to 2018-01-26 23:42:18.668000
# ......
# Writing 150 rows dated 2018-01-26 23:42:18.668000 to 2018-01-26 23:42:21.668000
# ...
# Writing 150 rows dated 2018-01-26 23:42:21.668000 to 2018-01-26 23:42:24.668000
# ...
# Writing 150 rows dated 2018-01-26 23:42:24.668000 to 2018-01-26 23:42:27.668000
# ...
# Writing 78 rows dated 2018-01-26 23:42:27.668000 to 2018-01-26 23:42:30.668000
# ..
# Writing 150 rows dated 2018-01-26 23:42:29.248000 to 2018-01-26 23:42:32.248000
# ...
# Writing 150 rows dated 2018-01-26 23:42:32.248000 to 2018-01-26 23:42:35.248000
# ...
# Writing 150 rows dated 2018-01-26 23:42:35.248000 to 2018-01-26 23:42:38.248000
# ...
# Writing 150 rows dated 2018-01-26 23:42:38.248000 to 2018-01-26 23:42:41.248000
# ...
# Writing 77 rows dated 2018-01-26 23:42:41.248000 to 2018-01-26 23:42:44.248000
